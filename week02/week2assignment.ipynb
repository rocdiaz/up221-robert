# %% [markdown]
# # Week 2 Assignment
# ## Data exploration
# ### This assignment aims to gain familiarity with exploring data. I will be using Parking Citations issued the year of 2023

# %% [markdown]
# # Here I am importing pandas in order to read the csv file

# %%
import pandas as pd

# %% [markdown]
# # This is to read and add the parking citation data to the notebook

# %%
df = pd.read_csv('Parking_Citations_2023.csv')

# %% [markdown]
# # Here I am trying to figure out how many rows and columns there are.
# ## We can see that it is hefty data as it contains 38,563 rows and 22 columns

# %%
df.shape

# %% [markdown]
# ## Here I am trying to see the data as a whole. Though I think because there are a lot of columns (22) it is a bit messy, it is exciting though to see longitude and latitude as Chris mentioned this can be translated into a geometry column.

# %%
df.info
# Out:
# <bound method DataFrame.info of        Ticket number  Issue Date  Issue time  Meter Id  Marked Time  \
# 0         4560616992  01/01/2023         248       NaN            0
# 1         4560782774  01/01/2023         244       NaN            0
# 2         4560617003  01/01/2023         250       NaN            0
# 3         4559831231  01/01/2023         322       NaN            0
# 4         4559831216  01/01/2023         317       NaN            0
# ...              ...         ...         ...       ...          ...
# 38558     4563080336  03/09/2023        2229       NaN            0
# 38559     4563545486  03/09/2023        2021       NaN            0
# 38560     4563669913  03/09/2023        1217       NaN            0
# 38561     4563663031  03/09/2023         824       NaN            0
# 38562     4563569076  03/09/2023         841       NaN            0
#
#       RP State Plate  Plate Expiry Date  VIN  Make Body Style  ... Route  \
# 0                 CA                  0  NaN   KIA         PA  ...   NaN
# 1                 CA             202312  NaN  FORD         PA  ...   NaN
# 2                 CA             202302  NaN  FORD         PA  ...   NaN
# 3                 CA             202306  NaN   BMW         PA  ...   NaN
# 4                 CA             202303  NaN  MITS         PA  ...   NaN
# ...              ...                ...  ...   ...        ...  ...   ...
# 38558             CA                  0  NaN  HOND         PA  ...   NaN
# 38559             CA             202311  NaN  DODG         PA  ...   NaN
# 38560             CA                  0  NaN  TSMR         PA  ...   NaN
# 38561             CA             202307  NaN  TOYT         PA  ...   NaN
# 38562             CA             202305  NaN   NaN        NaN  ...   NaN
#
#       Agency Violation code  Violation Description Fine amount      Latitude  \
# 0       51.0       80.56E4+               RED ZONE        93.0  6.449095e+06
# 1       53.0       80.56E4+               RED ZONE        93.0  6.425148e+06
# 2       51.0       80.56E4+               RED ZONE        93.0  6.449405e+06
# 3       54.0       80.56E4+               RED ZONE        93.0  6.463434e+06
# 4       54.0       80.56E4+               RED ZONE        93.0  6.463434e+06
# ...      ...            ...                    ...         ...           ...
# 38558   55.0       80.56E4+               RED ZONE        93.0  6.473588e+06
# 38559   55.0       80.56E4+               RED ZONE        93.0  6.481936e+06
# 38560   56.0       80.56E4+               RED ZONE        93.0  6.485798e+06
# 38561   51.0       80.56E4+               RED ZONE        93.0  6.461716e+06
# 38562    NaN            NaN                    NaN         NaN           NaN
#
#           Longitude    Agency Description  Color Description  \
# 0      1.813510e+06    51 - DOT - WESTERN              BLACK
# 1      1.906353e+06     53 - DOT - VALLEY               BLUE
# 2      1.813494e+06    51 - DOT - WESTERN              BLACK
# 3      1.855234e+06  54 - DOT - HOLLYWOOD              BEIGE
# 4      1.855234e+06  54 - DOT - HOLLYWOOD                RED
# ...             ...                   ...                ...
# 38558  1.825831e+06   55 - DOT - SOUTHERN              WHITE
# 38559  1.809300e+06   55 - DOT - SOUTHERN              BLACK
# 38560  1.837071e+06    56 - DOT - CENTRAL              WHITE
# 38561  1.837056e+06    51 - DOT - WESTERN              OTHER
# 38562           NaN                   NaN                NaN
#
#       Body Style Description
# 0              PASSENGER CAR
# 1              PASSENGER CAR
# 2              PASSENGER CAR
# 3              PASSENGER CAR
# 4              PASSENGER CAR
# ...                      ...
# 38558          PASSENGER CAR
# 38559          PASSENGER CAR
# 38560          PASSENGER CAR
# 38561          PASSENGER CAR
# 38562                    NaN
#
# [38563 rows x 22 columns]>

# %% [markdown]
# # Here I am getting a summary of the first five rows and all colmns to preview the data

# %%
df.head(5)
# Out:
#    Ticket number  Issue Date  Issue time  Meter Id  Marked Time  \
# 0     4560616992  01/01/2023         248       NaN            0
# 1     4560782774  01/01/2023         244       NaN            0
# 2     4560617003  01/01/2023         250       NaN            0
# 3     4559831231  01/01/2023         322       NaN            0
# 4     4559831216  01/01/2023         317       NaN            0
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style  ... Route Agency  \
# 0             CA                  0  NaN   KIA         PA  ...   NaN   51.0
# 1             CA             202312  NaN  FORD         PA  ...   NaN   53.0
# 2             CA             202302  NaN  FORD         PA  ...   NaN   51.0
# 3             CA             202306  NaN   BMW         PA  ...   NaN   54.0
# 4             CA             202303  NaN  MITS         PA  ...   NaN   54.0
#
#   Violation code  Violation Description Fine amount      Latitude  \
# 0       80.56E4+               RED ZONE        93.0  6.449095e+06
# 1       80.56E4+               RED ZONE        93.0  6.425148e+06
# 2       80.56E4+               RED ZONE        93.0  6.449405e+06
# 3       80.56E4+               RED ZONE        93.0  6.463434e+06
# 4       80.56E4+               RED ZONE        93.0  6.463434e+06
#
#       Longitude    Agency Description  Color Description  \
# 0  1.813510e+06    51 - DOT - WESTERN              BLACK
# 1  1.906353e+06     53 - DOT - VALLEY               BLUE
# 2  1.813494e+06    51 - DOT - WESTERN              BLACK
# 3  1.855234e+06  54 - DOT - HOLLYWOOD              BEIGE
# 4  1.855234e+06  54 - DOT - HOLLYWOOD                RED
#
#   Body Style Description
# 0          PASSENGER CAR
# 1          PASSENGER CAR
# 2          PASSENGER CAR
# 3          PASSENGER CAR
# 4          PASSENGER CAR
#
# [5 rows x 22 columns]

# %% [markdown]
# ## The following code will allow me to see my data plotted. Though it doesn't show much, I'm thinking of getting more data maybe for another area.

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Here I am going to see which make of car gets the most ticket citations. Though it isn't a surprise that Toyota and Honda are the top 2 makes as they are the most popular selling cars.

# %%
df['Make'].value_counts()
# Out:
# Make
# TOYT    7153
# HOND    4796
# NISS    3207
# FORD    3060
# CHEV    2758
#         ...
# IND        1
# DUES       1
# PLYM       1
# MACK       1
# FSKR       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ## Here I am looking at data specifically when the make is Honda. To me this data does not do much, but I think it would be more interesting to see it on a map.

# %%
df.loc[df['Make'] == 'HOND' , ]
# Out:
#        Ticket number  Issue Date  Issue time  Meter Id  Marked Time  \
# 6         4560512961  01/01/2023         312       NaN            0
# 8         4560512972  01/01/2023         316       NaN            0
# 23        4560361993  01/01/2023         623       NaN            0
# 29        4560693384  01/01/2023         603       NaN            0
# 32        4560369800  01/01/2023         533       NaN            0
# ...              ...         ...         ...       ...          ...
# 38538     4563733554  03/09/2023        1208       NaN            0
# 38548     4563712996  03/09/2023        2156       NaN            0
# 38551     4563212150  03/09/2023        2225       NaN            0
# 38554     4563421855  03/09/2023         827       NaN            0
# 38558     4563080336  03/09/2023        2229       NaN            0
#
#       RP State Plate  Plate Expiry Date  VIN  Make Body Style  ... Route  \
# 6                 CA             202306  NaN  HOND         PA  ...   NaN
# 8                 CA             202106  NaN  HOND         PA  ...   NaN
# 23                CA             202308  NaN  HOND         PA  ...   NaN
# 29                CA                  0  NaN  HOND         PA  ...   NaN
# 32                CA             202306  NaN  HOND         PA  ...   NaN
# ...              ...                ...  ...   ...        ...  ...   ...
# 38538             CA             202304  NaN  HOND         PA  ...   NaN
# 38548             CA             202401  NaN  HOND         PA  ...   NaN
# 38551             CA             202312  NaN  HOND         PA  ...   NaN
# 38554             CA             202307  NaN  HOND         PA  ...   NaN
# 38558             CA                  0  NaN  HOND         PA  ...   NaN
#
#       Agency Violation code  Violation Description Fine amount      Latitude  \
# 6       54.0       80.56E4+               RED ZONE        93.0  6.468879e+06
# 8       54.0       80.56E4+               RED ZONE        93.0  6.468879e+06
# 23      56.0       80.56E4+               RED ZONE        93.0  6.479306e+06
# 29      56.0       80.56E4+               RED ZONE        93.0  6.498271e+06
# 32      53.0       80.56E4+               RED ZONE        93.0  6.412111e+06
# ...      ...            ...                    ...         ...           ...
# 38538   55.0       80.56E4+               RED ZONE        93.0  6.471420e+06
# 38548   56.0       80.56E4+               RED ZONE        93.0  6.482721e+06
# 38551   56.0       80.56E4+               RED ZONE        93.0  9.999900e+04
# 38554   56.0       80.56E4+               RED ZONE        93.0  6.498705e+06
# 38558   55.0       80.56E4+               RED ZONE        93.0  6.473588e+06
#
#           Longitude    Agency Description  Color Description  \
# 6      1.841325e+06  54 - DOT - HOLLYWOOD               GREY
# 8      1.841325e+06  54 - DOT - HOLLYWOOD               GREY
# 23     1.842938e+06    56 - DOT - CENTRAL               GREY
# 29     1.850995e+06    56 - DOT - CENTRAL               GREY
# 32     1.893312e+06     53 - DOT - VALLEY             SILVER
# ...             ...                   ...                ...
# 38538  1.723820e+06   55 - DOT - SOUTHERN              BLACK
# 38548  1.840552e+06    56 - DOT - CENTRAL             SILVER
# 38551  9.999900e+04    56 - DOT - CENTRAL              BLACK
# 38554  1.831347e+06    56 - DOT - CENTRAL              BLACK
# 38558  1.825831e+06   55 - DOT - SOUTHERN              WHITE
#
#       Body Style Description
# 6              PASSENGER CAR
# 8              PASSENGER CAR
# 23             PASSENGER CAR
# 29             PASSENGER CAR
# 32             PASSENGER CAR
# ...                      ...
# 38538          PASSENGER CAR
# 38548          PASSENGER CAR
# 38551          PASSENGER CAR
# 38554          PASSENGER CAR
# 38558          PASSENGER CAR
#
# [4796 rows x 22 columns]
